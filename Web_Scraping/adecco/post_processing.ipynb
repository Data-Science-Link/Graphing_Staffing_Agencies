# %% [markdown]
# ### Import relevant libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import data and reorder columns

# %%
# Read in df
df = pd.read_csv('adecco.csv')

# Reorder columns
lst_col = ['job_name', 'category', 'job_type', 'salary','location', 'first_paragraph',
           'description', 'ref_number', 'scrape_datetime']
df = df[lst_col]

df.head(3)
# Out:
#                  job_name                                           category  \
# 0     Packaging Associate                            Warehouse - Pick / Pack
# 1  LT Assembly Specialist  Industrial & Manufacturing - Assembly / Produc...
# 2           Production Ad  Industrial & Manufacturing - Assembly / Produc...
#
#              job_type                    salary  \
# 0  Contract/Temporary  $ 15.5 - $ 17.05 / Hour
# 1  Contract/Temporary               $17.00/Hour
# 2  Contract/Temporary     $ 11 - $ 11.25 / Day
#
#                           location  \
# 0                Lincoln, Nebraska
# 1          Santa Clara, California
# 2  South Charleston, West Virginia
#
#                                      first_paragraph  \
# 0  Adecco is currently assisting a local client, ...
# 1  At Adecco, we are the workforce experts provid...
# 2  Adecco is currently hiring Production Operator...
#
#                                          description               ref_number  \
# 0  Adecco is currently assisting a local client, ...  US_EN_99_021067_1386145
# 1  At Adecco, we are the workforce experts provid...  US_EN_99_024068_1386183
# 2  Adecco is currently hiring Production Operator...  US_EN_99_023229_1293942
#
#               scrape_datetime
# 0  2020-09-05 17:26:47.378248
# 1  2020-09-05 17:26:47.899123
# 2  2020-09-05 17:26:48.458884

# %% [markdown]
# ### Text Manipulation

# %%
# Replace the parse_error with NA
df = df.replace('parse_error', np.nan).replace(' ', np.nan).replace('', np.nan)

# Remove non-needed characters from salary
def salary_formatter(s):
    return ''.join([i for i in str(s) if i.isnumeric() or i in ['.', '-'] ])
df['salary'] = df['salary'].apply(salary_formatter)

# Make new columns for low and high end salary 
df_salary_range = df["salary"].str.split("-", n = 1, expand = True)
df.insert(4, 'salary_low', df_salary_range[0])
df['salary_low'] = df['salary_low'].replace('', np.nan).astype(float)
df.insert(5, 'salary_high', df_salary_range[1])
df['salary_high'] = df['salary_high'].replace('', np.nan).astype(float)

# Recalculate salary
df['temp_code'] = df['salary_low'].isnull().map({True: 0, False: 1})
df['temp_code'] = df['temp_code'] + df['salary_high'].isnull().map({True: 0, False: 1})
df['salary'] = np.where(df['temp_code']==1, df['salary_low'], (df['salary_low'] + df['salary_high']) / 2)
del df['temp_code']
  
# Make new columns for city and state 
df_location = df["location"].str.split(",", n = 1, expand = True)
df.insert(7, 'city', df_location[0])
df['city'] = df['city'].replace('', np.nan)
df.insert(8, 'state', df_location[1])
df['state'] = df['state'].replace('', np.nan)
del df['location']

# Convert datetime
df['scrape_datetime'] = pd.to_datetime(df['scrape_datetime'], infer_datetime_format=True)  

df.head(3)
# Out:
#                  job_name                                           category  \
# 0     Packaging Associate                            Warehouse - Pick / Pack
# 1  LT Assembly Specialist  Industrial & Manufacturing - Assembly / Produc...
# 2           Production Ad  Industrial & Manufacturing - Assembly / Produc...
#
#              job_type  salary  salary_low  salary_high              city  \
# 0  Contract/Temporary  16.275        15.5        17.05           Lincoln
# 1  Contract/Temporary  17.000        17.0          NaN       Santa Clara
# 2  Contract/Temporary  11.125        11.0        11.25  South Charleston
#
#             state                                    first_paragraph  \
# 0        Nebraska  Adecco is currently assisting a local client, ...
# 1      California  At Adecco, we are the workforce experts provid...
# 2   West Virginia  Adecco is currently hiring Production Operator...
#
#                                          description               ref_number  \
# 0  Adecco is currently assisting a local client, ...  US_EN_99_021067_1386145
# 1  At Adecco, we are the workforce experts provid...  US_EN_99_024068_1386183
# 2  Adecco is currently hiring Production Operator...  US_EN_99_023229_1293942
#
#              scrape_datetime
# 0 2020-09-05 17:26:47.378248
# 1 2020-09-05 17:26:47.899123
# 2 2020-09-05 17:26:48.458884

# %% [markdown]
# ### Write to csv

# %%
df.to_csv('adecco_post_processed.csv', index=False)
